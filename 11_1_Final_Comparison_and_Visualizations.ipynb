# %%
import pickle
import numpy as np
import pandas as pd

# %%
import pickle
import numpy as np

data_dir = "/Users/samskanderi/Documents/Research_Project/SWANSF/code/results/"
model_name = ['SVM', 'MLPClassifier', 'KNN', 'RandomForest']
ousampling_name = ['Without Sampling', 'Smote', 'Adasyn', 'GNI', 'TimeGAN', 'RusTomekSmote', 'RusTomekAdasyn', 'RusTomekGNI', 'RusTomekTimeGAN']


values = np.zeros((36,4))
count = 0
for name in model_name:
    for s_name in ousampling_name:
        if s_name == 'Without Sampling':
            with open(data_dir + name + '_NewFeatures_Results' + ".pkl", 'rb') as f:
                values[count,:] = [arr[6] for arr in pickle.load(f)]
                count += 1
        else:
            with open(data_dir + name + '_' + s_name + '_WithoutC_NewFeatures_Results' + ".pkl", 'rb') as f:
                values[count,:] = [arr[6] for arr in pickle.load(f)]
                count += 1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Use seaborn style

# Adjust font settings for better readability
font = {'family': 'Tahoma', 'weight': 'normal', 'size': 10}
plt.rc('font', **font)

# Models and sampling techniques
models = ['SVM', 'MLP', 'KNN', 'RF']
sampling = ['Without Sampling', 'Smote', 'Adasyn', 'GNI', 'TimeGAN', 'RUS-Tomek_Smote', 'RUS-Tomek_Adasyn', 'RUS-Tomek_GNI', 'RUS-Tomek_TimeGAN']

tss_values_mean = [np.mean(values[i, :]) for i in range(36)]
tss_values_max = [np.max(values[i, :]) for i in range(36)]

# Generate labels for each bar
labels = [f'{model}({samp})' for model in models for samp in sampling]

fig, ax = plt.subplots(figsize=(9, 9))

# Define improved colors for the groups
colors = ['#f8d3a6', '#f3b86f', '#EE9322', '#adc8e7', '#709ed5', '#3876BF', '#d5b8e6', '#b683d4', '#974EC3', '#becebf', '#8daa90', '#618264']  # Blue, Orange, Green


bars = plt.barh(labels[0:1], tss_values_max[0:1], color=colors[0], alpha = 0.65)
bars += plt.barh(labels[1:5], tss_values_max[1:5], color=colors[1], alpha = 0.65)
bars += plt.barh(labels[5:9], tss_values_max[5:9], color=colors[2], alpha = 0.65)
bars += plt.barh(labels[9:10], tss_values_max[9:10], color=colors[3], alpha = 0.65)
bars += plt.barh(labels[10:14], tss_values_max[10:14], color=colors[4], alpha = 0.65)
bars += plt.barh(labels[14:18], tss_values_max[14:18], color=colors[5], alpha = 0.65)
bars += plt.barh(labels[18:19], tss_values_max[18:19], color=colors[6], alpha = 0.65)
bars += plt.barh(labels[19:23], tss_values_max[19:23], color=colors[7], alpha = 0.65)
bars += plt.barh(labels[23:27], tss_values_max[23:27], color=colors[8], alpha = 0.65)
bars += plt.barh(labels[27:28], tss_values_max[27:28], color=colors[9], alpha = 0.65)
bars += plt.barh(labels[28:32], tss_values_max[28:32], color=colors[10], alpha = 0.65)
bars += plt.barh(labels[32:36], tss_values_max[32:36], color=colors[11], alpha = 0.65)

# Add TSS values on top of each bar
for bar in bars:
    width = bar.get_width()
    label_x_pos = width + 0.01
    plt.text(label_x_pos, bar.get_y() + bar.get_height() / 2, f'{width:.2f}', va='center')
    

    # Create bars with specific colors
bars = plt.barh(labels[0:1], tss_values_mean[0:1], color=colors[0])
bars += plt.barh(labels[1:5], tss_values_mean[1:5], color=colors[1])
bars += plt.barh(labels[5:9], tss_values_mean[5:9], color=colors[2])
bars += plt.barh(labels[9:10], tss_values_mean[9:10], color=colors[3])
bars += plt.barh(labels[10:14], tss_values_mean[10:14], color=colors[4])
bars += plt.barh(labels[14:18], tss_values_mean[14:18], color=colors[5])
bars += plt.barh(labels[18:19], tss_values_mean[18:19], color=colors[6])
bars += plt.barh(labels[19:23], tss_values_mean[19:23], color=colors[7])
bars += plt.barh(labels[23:27], tss_values_mean[23:27], color=colors[8])
bars += plt.barh(labels[27:28], tss_values_mean[27:28], color=colors[9])
bars += plt.barh(labels[28:32], tss_values_mean[28:32], color=colors[10])
bars += plt.barh(labels[32:36], tss_values_mean[32:36], color=colors[11])

# Add TSS values on top of each bar
for bar in bars:
    width = bar.get_width()
    label_x_pos = width - 0.04
    plt.text(label_x_pos, bar.get_y() + bar.get_height() / 2, f'{width:.2f}', va='center', color = 'white')



# Set labels and title
plt.xlabel('TSS Value')
plt.ylabel('Sampling Technique')
plt.title('Mean and Max TSS Values for Different Sampling Techniques')

ax.set_xlim(.18, .95)  # Adjust the x-axis limit


plt.tight_layout()
plt.savefig('approach1_sampling.pdf')


# Show the plot
plt.show()

# %%
import pickle
import numpy as np

data_dir = "/Users/samskanderi/Documents/Research_Project/SWANSF/code/results/"
model_name = ['SVM', 'MLPClassifier', 'KNN', 'RandomForest']
ousampling_name = ['_ZM', '_MM', '_ZN', '_MN', '']


values = np.zeros((20,4))
count = 0
for name in model_name:
    for s_name in ousampling_name:
        with open(data_dir + name + '_NewFeatures' + s_name + '_Results' + ".pkl", 'rb') as f:
            values[count,:] = [arr[6] for arr in pickle.load(f)]
            count += 1

            
models = ['SVM', 'MLP', 'KNN', 'RF']
sampling = ['Mean-Imput + Zscore-Norm', 'Mean-Imput + MinMax-Norm', \
            'Nextvalue-Imput + Zscore-Norm', 'Nextvalue-Imput + MinMax-Norm', \
            'Our Imput and Norm', ]
names = [f'{model}({samp})' for model in models for samp in sampling]

# %%
import matplotlib.pyplot as plt
import seaborn as sns



# Adjust font settings for better readability
font = {'family': 'Tahoma', 'weight': 'normal', 'size': 10}
plt.rc('font', **font)

tss_values_mean = [np.mean(values[i, :]) for i in range(20)]
tss_values_max = [np.max(values[i, :]) for i in range(20)]
    
labels = names

# Create the bar plot
fig, ax = plt.subplots(figsize=(9, 5))

# Define improved colors for the groups
colors = ['#f3b86f', '#EE9322', '#709ed5', '#3876BF', '#b683d4', '#974EC3', '#8daa90', '#618264']  # Blue, Orange, Green


bars = plt.barh(labels[0:4], tss_values_max[0:4], color=colors[0], alpha = 0.6)
bars += plt.barh(labels[4:5], tss_values_max[4:5], color=colors[1], alpha = 0.6)
bars += plt.barh(labels[5:9], tss_values_max[5:9], color=colors[2], alpha = 0.6)
bars += plt.barh(labels[9:10], tss_values_max[9:10], color=colors[3], alpha = 0.6)
bars += plt.barh(labels[10:14], tss_values_max[10:14], color=colors[4], alpha = 0.6)
bars += plt.barh(labels[14:15], tss_values_max[14:15], color=colors[5], alpha = 0.6)
bars += plt.barh(labels[15:19], tss_values_max[15:19], color=colors[6], alpha = 0.6)
bars += plt.barh(labels[19:20], tss_values_max[19:20], color=colors[7], alpha = 0.6)

# Add TSS values on top of each bar
for bar in bars:
    width = bar.get_width()
    label_x_pos = width + 0.01
    plt.text(label_x_pos, bar.get_y() + bar.get_height() / 2, f'{width:.2f}', va='center')
    

    # Create bars with specific colors
bars = plt.barh(labels[0:4], tss_values_mean[0:4], color=colors[0])
bars += plt.barh(labels[4:5], tss_values_mean[4:5], color=colors[1])
bars += plt.barh(labels[5:9], tss_values_mean[5:9], color=colors[2])
bars += plt.barh(labels[9:10], tss_values_mean[9:10], color=colors[3])
bars += plt.barh(labels[10:14], tss_values_mean[10:14], color=colors[4])
bars += plt.barh(labels[14:15], tss_values_mean[14:15], color=colors[5])
bars += plt.barh(labels[15:19], tss_values_mean[15:19], color=colors[6])
bars += plt.barh(labels[19:20], tss_values_mean[19:20], color=colors[7])

# Add TSS values on top of each bar
for bar in bars:
    width = bar.get_width()
    label_x_pos = width - 0.04
    plt.text(label_x_pos, bar.get_y() + bar.get_height() / 2, f'{width:.2f}', va='center', color = 'white')



# Set labels and titlez
plt.xlabel('TSS Value')
plt.ylabel('Different Imputation-Normalizatio')
plt.title('Mean and Max TSS Values for Different Imputation-Normalization Techniques')

ax.set_xlim(.0, .88)  # Adjust the x-axis limit

plt.tight_layout()
plt.savefig('approach1_preprocessing.pdf')

# Show the plot
plt.show()

# %%
import pickle
import numpy as np

data_dir = "/Users/samskanderi/Documents/Research_Project/SWANSF/code/results/"
model_name = ['SVM', 'MLPClassifier', 'KNN', 'RandomForest']
ousampling_name = ['Without Sampling', 'Smote', 'Adasyn', 'GNI', 'TimeGAN', 'RusTomekSmote', 'RusTomekAdasyn', 'RusTomekGNI', 'RusTomekTimeGAN']

tss_values = np.zeros((36,4))
recall_values = np.zeros((36,4))
count = 0
for name in model_name:
    for s_name in ousampling_name:
        if s_name == 'Without Sampling':
            with open(data_dir + name + '_NewFeatures_Results' + ".pkl", 'rb') as f:
                pkl = pickle.load(f)
                tss_values[count,:] = [arr[6] for arr in pkl]
                recall_values[count,:] = [arr[10] for arr in pkl]
                count += 1
        else:
            with open(data_dir + name + '_' + s_name + '_WithoutC_NewFeatures_Results' + ".pkl", 'rb') as f:
                pkl = pickle.load(f)
                tss_values[count,:] = [arr[6] for arr in pkl]
                recall_values[count,:] = [arr[10] for arr in pkl]
                count += 1

                
tss_values_mean = [np.mean(tss_values[i, :]) for i in range(36)]
tss_values_max = [np.max(tss_values[i, :]) for i in range(36)]

recall_values_mean = [np.mean(recall_values[i, :]) for i in range(36)]
recall_values_max = [np.max(recall_values[i, :]) for i in range(36)]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_style("darkgrid")

values = {
    'X' : tss_values_max,
    
    'Y' : recall_values_max,
    
    'Z': tss_values_mean,
    
    'Class' : ['Without Sampling', 'Over Sampling', 'Over Sampling', 'Over Sampling', 'Over Sampling', 'Both Over & Under Sampling', 'Both Over & Under Sampling', 'Both Over & Under Sampling', 'Both Over & Under Sampling',
              'Without Sampling', 'Over Sampling', 'Over Sampling', 'Over Sampling', 'Over Sampling', 'Both Over & Under Sampling', 'Both Over & Under Sampling', 'Both Over & Under Sampling', 'Both Over & Under Sampling',
              'Without Sampling', 'Over Sampling', 'Over Sampling', 'Over Sampling', 'Over Sampling', 'Both Over & Under Sampling', 'Both Over & Under Sampling', 'Both Over & Under Sampling', 'Both Over & Under Sampling',
              'Without Sampling', 'Over Sampling', 'Over Sampling', 'Over Sampling', 'Over Sampling', 'Both Over & Under Sampling', 'Both Over & Under Sampling', 'Both Over & Under Sampling', 'Both Over & Under Sampling'],
}


df = pd.DataFrame(values)

# Create a beautiful violin plot with Seaborn
plt.figure(figsize=(6, 4))

sns.scatterplot(data=df[df['Class'] == 'Without Sampling'], x='X', y='Y', label='Without Sampling', marker='o', color = 'red', size='Z', sizes=(50,100),legend=False, alpha=0.65)

# Plot Class B in red with squares
sns.scatterplot(data=df[df['Class'] == 'Over Sampling'], x='X', y='Y', label='Over Sampling', marker='o', color = 'blue', size='Z', sizes=(50,100),legend=False, alpha=0.65)

# Plot Class C in green with triangles
sns.scatterplot(data=df[df['Class'] == 'Both Over & Under Sampling'], x='X', y='Y', label='Both Over & Under Sampling', marker='o', color = 'green', size='Z', sizes=(30,80),legend=False, alpha=0.65)


# Customize the plot
plt.title("Max TSS and Recall Values After and Before Sampling")
plt.xlabel("TSS")
plt.ylabel("Recall")

ax = plt.gca()
ax.set_xlim(.47, .9)  # Set the x-axis limits from 2 to 7
ax.set_ylim(.46, 1.05)  # Set the y-axis limits from 3 to 8
plt.grid(axis="y")

# Show the plot
plt.legend(fontsize='x-small')

plt.tight_layout()
plt.savefig('approach1_sampling_tssrecall.pdf')


plt.show()

# %%
import pickle
import numpy as np

data_dir = "/Users/samskanderi/Documents/Research_Project/SWANSF/code/results/"
model_name = ['SVM', 'MLPClassifier', 'KNN', 'RandomForest']
ousampling_name = ['_ZM', '_MM', '_ZN', '_MN', '']


tss_values = np.zeros((20,4))
recall_values = np.zeros((20,4))
count = 0
for name in model_name:
    for s_name in ousampling_name:
        with open(data_dir + name + '_NewFeatures' + s_name + '_Results' + ".pkl", 'rb') as f:
            pkl = pickle.load(f)
            tss_values[count,:] = [arr[6] for arr in pkl]
            recall_values[count,:] = [arr[10] for arr in pkl]
            count += 1

            
names = [f'{model}({samp})' for model in models for samp in sampling]


tss_values_mean = [np.mean(tss_values[i, :]) for i in range(20)]
tss_values_max = [np.max(tss_values[i, :]) for i in range(20)]

recall_values_mean = [np.mean(recall_values[i, :]) for i in range(20)]
recall_values_max = [np.max(recall_values[i, :]) for i in range(20)]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_style("darkgrid")



values = {
    'X' : tss_values_max,
    
    'Y' : recall_values_max,
    
    'Z': tss_values_mean,
    
    'Class' : ['MeanImput + ZscoreNorm', 'MeanImput + MinMaxNorm', 'NextvalueImput + ZscoreNorm', 'NextvalueImput + MinMaxNorm', 'Our Imput and Norm', 
              'MeanImput + ZscoreNorm', 'MeanImput + MinMaxNorm', 'NextvalueImput + ZscoreNorm', 'NextvalueImput + MinMaxNorm', 'Our Imput and Norm', 
              'MeanImput + ZscoreNorm', 'MeanImput + MinMaxNorm', 'NextvalueImput + ZscoreNorm', 'NextvalueImput + MinMaxNorm', 'Our Imput and Norm',
              'MeanImput + ZscoreNorm', 'MeanImput + MinMaxNorm', 'NextvalueImput + ZscoreNorm', 'NextvalueImput + MinMaxNorm', 'Our Imput and Norm',],
}


df = pd.DataFrame(values)

# Create a beautiful violin plot with Seaborn
plt.figure(figsize=(6, 4))

sns.scatterplot(data=df[df['Class'] == 'MeanImput + ZscoreNorm'], x='X', y='Y', label='MeanImput + ZscoreNorm', marker='o', color = 'red', size='Z', sizes=(30,80),legend=False, alpha=0.65)

# Plot Class B in red with squares
sns.scatterplot(data=df[df['Class'] == 'NextvalueImput + ZscoreNorm'], x='X', y='Y', label='NextvalueImput + ZscoreNorm', marker='o', color = 'red', size='Z', sizes=(30,80),legend=False, alpha=0.65)

# Plot Class B in red with squares
sns.scatterplot(data=df[df['Class'] == 'MeanImput + MinMaxNorm'], x='X', y='Y', label='MeanImput + MinMaxNorm', marker='o', color = 'blue', size='Z', sizes=(30,80),legend=False, alpha=0.65)

# Plot Class C in green with triangles
sns.scatterplot(data=df[df['Class'] == 'NextvalueImput + MinMaxNorm'], x='X', y='Y', label='NextvalueImput + MinMaxNorm', marker='o', color = 'blue', size='Z', sizes=(30,80),legend=False, alpha=0.65)

# Plot Class C in green with triangles
sns.scatterplot(data=df[df['Class'] == 'Our Imput and Norm'], x='X', y='Y', label='Our Imput and Norm', marker='o', color = 'green', size='Z', sizes=(30,80),legend=False, alpha=0.65)


# Customize the plot
plt.title("Max TSS and Recall Values for Different Imputation-Normalization")
plt.xlabel("TSS")
plt.ylabel("Recall")

ax = plt.gca()
ax.set_xlim(0, .9)  # Set the x-axis limits from 2 to 7
ax.set_ylim(0, .95)  # Set the y-axis limits from 3 to 8
plt.grid(axis="y")

# Show the plot
plt.legend(fontsize='x-small', loc='upper left')

plt.tight_layout()
plt.savefig('approach1_preprocessing_tssrecall.pdf')


plt.show()
